% %% [markdown]
% **Code for figures \[9, 15\]**
%
%
% The following code generates Figures from 9 to 15.

% %%
%% Figures 9-15
Xsel=citiesItaly2024(:,{'Employm' 'Protest' 'UrbanFra'});

ShapeFile=citiesItaly2024.Properties.UserData{1};
out=pcaFS(Xsel,'ShapeFile',ShapeFile);
% Out:
% Initial correlation matrix
%                 Employm    Protest    UrbanFra
%                 _______    _______    ________
%     Employm       1.00      -0.31      -0.90
%     Protest      -0.31       1.00       0.23
%     UrbanFra     -0.90       0.23       1.00
% Explained variance by PCs
%            Eigenvalues    Explained_Variance    Explained_Variance_cum
%            ___________    __________________    ______________________
%     PC1       2.04              67.98                    67.98
%     PC2       0.86              28.75                    96.73
%     PC3       0.10               3.27                   100.00
% Loadings = correlations between variables and PCs
%                  PC1      PC2
%                 _____    _____
%     Employm     -0.96     0.18
%     Protest      0.49     0.87
%     UrbanFra     0.94    -0.28
% Communalities
%                 PC1     PC2     PC1-PC2
%                 ____    ____    _______
%     Employm     0.92    0.03     0.95
% ...

% %% [markdown]
% <center><img src="data:image/png;base64,..." width="491" alt="figure_2.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="491" alt="figure_3.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="491" alt="figure_4.png"></center>
