% %% [markdown]
% **Code for figures \[17, 18\]**
%
%
% The following code generates Figures from 17 to 18.

% %%
%% Figure 17-18
% please note that to obtain the same appearance of Figures 17 and 18
% of the paper you should manually rotate the plots.
figure
pcaProjection(Xsel)
% Out:
% <center><img src="data:image/png;base64,..." width="450" alt="figure_0.png"></center>
% <center><img src="data:image/png;base64,..." width="450" alt="figure_1.png"></center>

% %% [markdown]
% <center><img src="data:image/png;base64,..." width="450" alt="figure_2.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="450" alt="figure_3.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="450" alt="figure_4.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="450" alt="figure_5.png"></center>
